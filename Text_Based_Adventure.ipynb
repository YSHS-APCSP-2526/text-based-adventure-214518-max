# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/text-based-adventure-214518-max/blob/main/Text_Based_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Requirements for text based adventure
# 1. You must have at least 2 different "paths" that are at least 4 decisions in length
# 2. Include an element of randomness (from the random library)
# 3. Include a list that is core to the text based adventure
# 4. Include a function that is called within your program that includes a while loop, and a parameter that influences a conditional statement in your function.
# 5. Commented Code.
# 6. A [digital flowchart](https://docs.google.com/document/d/1p2k3wL6gzjYWBuWxwEQptmbbOZZNsQrthlC12SNtYgY/edit?usp=sharing) that follows accepted symbols for representing code. You can use google slides or [draw.io](https://www.drawio.com/) for the flowchart.

# %%
def main():
  response = intro()
  response = sharkRoom()
  response = thresher()
  response = leopard()
  response = fishRoom()
  response = mahi()
  response = clownFish()

# %%
def intro():
  response = input("Do you want to learn about the fish or the sharks first? Fish or Sharks: ")
  return response

# %%
def sharkRoom():
  response = input("You have now entered the shark exibate, do you want to learn about the Thresher shark or the Leopard Shark? Thresher or Leopard: ")
  return response

# %%
def thresher():
  response = input("Fun Fact: The Treaher Shark uses it long wip like tail to stun its prey before eatting it. Now move on the next exibate! Yes/No: ")
  return response

# %%
def leopard():
  response = input("Fun Fact: The older the shark is the lighter their spots are going to be. Now move on the next exibate! Yes/No: ")
  return response

# %%
def fishRoom():
  response = input("You have enter the fish exibate, would you like to learn about the Mahi-Mahi fish or the school of Clownfish? Mahi-Mahi or Clowfish: ")
  return response

# %%
def mahi():
  response = input("Fun Fact: The vibrant colors on the fish can change due to stress, exitment, and even death. Now move on the next exibate! Yes/No: ")
  return response

# %%
def clownFish():
  response = input("Fun Fact: all clown fish are born male but if the dominate female dies, the next dominate male will turn in to a female. Now move on the next exibate! Yes/No:  ")

# %%
def Yes():
  response = input("Would you like to learn about Rays or Whales? ")

# %%
def newExibates(response):
  print(response)
  if response == "Yes"

# %%
def sharkExibate(response):
  print(response)
  if response == "Thresher":
    thresher()
  elif response == "Leopard":
    leopard()

# %%
def fishExibate(response):
  print(response)
  if response == "Mahi":
    mahi()
  elif response == "Clownfish":
    clownFish()

# %%
def main():
  response = intro()
  if response == "Fish":
    response = fishRoom()
    fishExibate(response)

  elif response == "Sharks":
    response = sharkRoom()
    sharkExibate(response)

# %%
main()
# Out:
# Do you want to learn about the fish or the sharks first? Fish or Sharks: Sharks
# You have now entered the shark exibate, do you want to learn about the Thresher shark or the Leopard Shark? Thresher or Leopard: Thresher
# Thresher
# Fun Fact: The Treaher Shark uses it long wip like tail to stun its prey before eatting it. Now move on the next exibate! Yes/No: yes
