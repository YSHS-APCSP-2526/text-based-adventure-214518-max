# %% [markdown]
# <a href="https://colab.research.google.com/github/YSHS-APCSP-2526/text-based-adventure-214518-max/blob/main/Mason_AutoSave_of_Text_Based_Adventure.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Requirements for text based adventure
# 1. You must have at least 2 different "paths" that are at least 4 decisions in length
# 2. Include an element of randomness (from the random library)
# 3. Include a list that is core to the text based adventure
# 4. Include a function that is called within your program that includes a while loop, and a parameter that influences a conditional statement in your function.
# 5. Commented Code.
# 6. A [digital flowchart](https://docs.google.com/document/d/1p2k3wL6gzjYWBuWxwEQptmbbOZZNsQrthlC12SNtYgY/edit?usp=sharing) that follows accepted symbols for representing code. You can use google slides or [draw.io](https://www.drawio.com/) for the flowchart.

# %%
def main():
  response = intro()
  response = sharkRoom()
  response = thresher()
  response = leopard()
  response = fishRoom()
  response = mahi()
  response = clownFish()
  response = newExhibate()
  response = rayRoom()
  response = eagle()
  response = manta
  response = whaleRoom()
  response = blue()
  response = beluga()
  response = fishExhibate()
  response = sharkExhibate()
  response = rayExhibate()
  response = whaleExhibate()

# %%
def intro():
  response = input("Do you want to learn about the fish or the sharks first? Fish or Sharks: ")
  return response

# %%
def sharkRoom():
  response = input("You have now entered the shark exibate, do you want to learn about the Thresher shark or the Leopard Shark? Thresher or Leopard: ")
  return response

# %%
def thresher():
  response = input("Fun Fact: The Treaher Shark uses it long wip like tail to stun its prey before eatting it.")

# %%
def leopard():
  response = input("Fun Fact: The older the shark is the lighter their spots are going to be.")

# %%
def fishRoom():
  response = input("You have enter the fish exibate, would you like to learn about the Mahi-Mahi fish or the school of Clownfish? Mahi-Mahi or Clowfish: ")
  return response

# %%
def mahi():
  response = input("Fun Fact: The vibrant colors on the fish can change due to stress, exitment, and even death.")
  return response

# %%
def clownFish():
  print("Fun Fact: all clown fish are born male but if the dominate female dies, the next dominate male will turn in to a female.  ")

# %%
def newExhibate():
  response = input("Would you like to learn about Rays or Whales? Rays or Whales:  ")
  return response

# %%
def rayRoom():
  response = input("You have now entered the Ray room, would you like to learn about Eagle rays or Manta Rays? Eagle or Manta: ")
  return response

# %%
def eagle():
  response = input("Fun Fact: Eagle rays can entirly leap out of the water: ")
  return response

# %%
def manta():
  response = input("Fun Fact: Manta rays have the largest brain to body ratio out of all warm blooded fish: ")
  return response

# %%
def whaleRoom():
  response = input("You have now entered the Whale room, would you like tp learn about the Blue whale or the Beluga whale? Blue or Beluga: ")

# %%
def blue():
  response = input("Fun Fact: A blue whales heart is about the same size as a Voltzwagen bettal: ")
  return response

# %%
def beluga():
  response = input("Fun Fact: A Beluga whale is the only whale that can turn its head and can swim backwards: ")

# %%
def moveToNewExhibit():
  response = input("Do you want to move to a new exhibit? Yes or No")
  return response

# %%
def sharkExhibate(response):
  print(response)
  if response == "Thresher":
    thresher()
  elif response == "Leopard":
    leopard()

# %%
def fishExhibate(response):
  print(response)
  if response == "Mahi":
    mahi()
  elif response == "Clownfish":
    clownFish()

# %%
def rayExhibate(response):
  print(response)
  if response == "Eagle":
    eagle()
  elif response == "Manta":
    manta()

# %%
def whaleExhibate(response):
  print(response)
  if response == "Blue":
    blue()
  elif response == "Beluga":
    beluga()

# %%
def main():
  response = intro()
  if response == "Fish":
    response = fishRoom()
    fishExhibate(response)

    response=moveToNewExhibit()

    if response == "Yes":
      response = input("Do you want to learn about Rays or Whales?")


      if response == "Rays":
        response = rayRoom()
        rayExhibate(response)
      elif response == "Whales":
        response = whaleRoom()
        whaleExhibate(response)
    else:
      intro()

  elif response == "Sharks":
    response = sharkRoom()
    sharkExhibate(response)

    response=moveToNewExhibit()

    if response == "Yes":
      response = input("Do you want to learn about Rays or Whales?")

    if response == "Rays":
      response = rayRoom()
      rayExhibate(response)
    elif response == "Whales":
      response = whaleRoom()
      whaleExhibate(response)

# %%
main()
# Out:
# Do you want to learn about the fish or the sharks first? Fish or Sharks: Sharks
# You have now entered the shark exibate, do you want to learn about the Thresher shark or the Leopard Shark? Thresher or Leopard: Thresher
# Thresher
